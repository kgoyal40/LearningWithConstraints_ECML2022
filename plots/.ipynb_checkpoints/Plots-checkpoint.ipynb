# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (5, 5)
axes = plt.gca()
axes.set_xlim([-3, 3])
axes.set_ylim([-3, 3])

plt.plot([-1], [0], marker='o', markersize=3, color="red")
plt.plot([1], [0.5], marker='o', markersize=3, color="blue")

pac = mpatches.Arc([-1, 0], 0.8, 0.8, theta1=0, theta2=90, edgecolor='red', ls = '--', alpha=1)
plt.gca().add_patch(pac)

plt.plot([-0.6, -0.6], [0, -3], 'red', lw=1, ls='--', alpha=1)
plt.plot([-3, -1], [0.4, 0.4], 'red', lw=1, ls='--', alpha=1)

pac = mpatches.Arc([1, 0.5], 0.8, 0.8, theta1=180, theta2=270, edgecolor='blue', ls = '--', alpha=1)

plt.gca().add_patch(pac)

plt.plot([0.6, 0.6], [0.4, 3], 'blue', lw=1, ls='--', alpha=1)
plt.plot([1, 3], [0.1, 0.1], 'blue', lw=1, ls='--', alpha=1)

plt.fill_between([-3, 0.6], [3, 3], [0.4, 0.4], color='grey', alpha=0.3)
plt.fill_between([-0.6, 3], [-3, -3], [0.1, 0.1], color='grey', alpha=0.3)
plt.fill_between([-0.6, 0.6], [0.11, 0.11], [0.3999, 0.3999], color='grey', alpha=0.3)

# %%
delta = 0.1
x = np.arange(-2.0, 2.0, delta)
y = np.arange(-2, 2, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(0.3*(-X**2 - 3*Y**2))
# Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
# Z = (Z1 - Z2) * 2

fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (15, 15)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 30
plt.rcParams.update({'figure.autolayout': True})

CS = ax.contour(X, Y, Z1, linewidths=2)
# ax.set_title('SaDe: Satisfiability Descent')

plt.arrow(-1.75 + 0.15 + 0.1 + 0.24 + 0.1 + 0.2, 0.75 + -0.2 + -0.25 + -0.19 + -0.25 + 0.1, 0.25, -0.05, length_includes_head=True, head_width=0.04, head_length=0.02)

pac = mpatches.Wedge([-1.75, 0.75], 0.3, theta1=270, theta2=360, facecolor='xkcd:orange', edgecolor='orange', ls = '--', alpha=0.8)
plt.gca().add_patch(pac)
plt.arrow(-1.75, 0.75, 0.15, -0.2, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

pac = mpatches.Wedge([-1.75 + 0.15, 0.75 + -0.2], 0.3, theta1=270, theta2=360, facecolor='xkcd:orange', edgecolor='orange', ls = '--', alpha=0.8)
plt.gca().add_patch(pac)
plt.arrow(-1.75 + 0.15, 0.75 + -0.2, 0.1, -0.25, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

pac = mpatches.Wedge([-1.75 + 0.15 + 0.1, 0.75 + -0.2 + -0.25], 0.3, theta1=270, theta2=360, facecolor='xkcd:orange', edgecolor='orange', ls = '--', alpha=0.8)
plt.gca().add_patch(pac)
plt.arrow(-1.75 + 0.15 + 0.1, 0.75 + -0.2 + -0.25, 0.24, -0.19, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

pac = mpatches.Wedge([-1.75 + 0.15 + 0.1 + 0.24, 0.75 + -0.2 + -0.25 + -0.19], 0.3, theta1=270, theta2=360, facecolor='xkcd:orange', edgecolor='orange', ls = '--', alpha=0.8)
plt.gca().add_patch(pac)
plt.arrow(-1.75 + 0.15 + 0.1 + 0.24, 0.75 + -0.2 + -0.25 + -0.19, 0.1, -0.25, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

pac = mpatches.Wedge([-1.75 + 0.15 + 0.1 + 0.24 + 0.1, 0.75 + -0.2 + -0.25 + -0.19 + -0.25], 0.3, theta1=0, theta2=90, facecolor='xkcd:orange', edgecolor='orange', ls = '--', alpha=0.8)
plt.gca().add_patch(pac)
plt.arrow(-1.75 + 0.15 + 0.1 + 0.24 + 0.1, 0.75 + -0.2 + -0.25 + -0.19 + -0.25, 0.2, 0.1, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

pac = mpatches.Wedge([-1.75 + 0.15 + 0.1 + 0.24 + 0.1 + 0.2, 0.75 + -0.2 + -0.25 + -0.19 + -0.25 + 0.1], 0.3, theta1=270, theta2=360, facecolor='xkcd:orange', edgecolor='orange', ls = '--', alpha=0.8)
plt.gca().add_patch(pac)
plt.arrow(-1.75 + 0.15 + 0.1 + 0.24 + 0.1 + 0.2, 0.75 + -0.2 + -0.25 + -0.19 + -0.25 + 0.1, 0.25, -0.05, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

ax.set_yticklabels([])
ax.set_xticklabels([])
# plt.axis('off')
plt.axis('square')
plt.savefig('SaDe.png')

# %%
delta = 0.1
x = np.arange(-2.0, 2.0, delta)
y = np.arange(-2, 2, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(0.3*(-X**2 - 3*Y**2))
# Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
# Z = (Z1 - Z2) * 2

fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (15, 15)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 50
plt.rcParams.update({'figure.autolayout': True})

CS = ax.contour(X, Y, Z1, linewidths=2)
# ax.set_title('SaDe: Satisfiability Descent')

pac = mpatches.Wedge([-1.75, 0.75], 0.5, theta1=270, theta2=360, facecolor='xkcd:grey', edgecolor='grey', ls = '--', alpha=0.3)
plt.gca().add_patch(pac)
plt.arrow(-1.75, 0.75, 0.25, -0.3, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

pac = mpatches.Wedge([-1.75 + 0.25, 0.75 - 0.3], 0.5, theta1=270, theta2=360, facecolor='xkcd:grey', edgecolor='grey', ls = '--', alpha=0.3)
plt.gca().add_patch(pac)
plt.arrow(-1.75 + 0.25, 0.75 - 0.3, 0.4, -0.15, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

pac = mpatches.Wedge([-1.75 + 0.25 + 0.4, 0.75 - 0.3 - 0.15], 0.5, theta1=270, theta2=360, facecolor='xkcd:grey', edgecolor='grey', ls = '--', alpha=0.3)
plt.gca().add_patch(pac)
plt.arrow(-1.75 + 0.25 + 0.4, 0.75 - 0.3 - 0.15, 0.3, -0.35, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

plt.annotate(s='', xy=(-1.75, 0.8), xytext=(-1.75 + 0.5, 0.80), arrowprops=dict(arrowstyle='<->'))
plt.text(-1.75 + 0.2, 0.85, r'$\alpha$', fontsize=40)

ax.set_yticklabels([])
ax.set_xticklabels([])
# plt.axis('off')
plt.axis('square')
plt.savefig('SaDe_2.png')
# Out:
# <ipython-input-4-19048af9dabc>:32: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.annotate(s='', xy=(-1.75, 0.8), xytext=(-1.75 + 0.5, 0.80), arrowprops=dict(arrowstyle='<->'))

# %%
delta = 0.1
x = np.arange(-2.0, 2.0, delta)
y = np.arange(-2, 2, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(0.3*(-X**2 - 3*Y**2))
# Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
# Z = (Z1 - Z2) * 2

fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (10, 10)
# plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 35
plt.rcParams.update({'figure.autolayout': True})

CS = ax.contour(X, Y, Z1, linewidths=2)
# ax.set_title('SaDe: Satisfiability Descent')

# pac = mpatches.Wedge([-1.75, 0.75], 0.5, theta1=270, theta2=360, facecolor='xkcd:grey', edgecolor='grey', ls = '--', alpha=0.3)
# plt.gca().add_patch(pac)
plt.arrow(-1.75, 0.75, 0.3, -0.3, length_includes_head=True, head_width=0.05, head_length=0.1, linewidth=2)

plt.annotate(s='', xy=(-1.75, 0.8), xytext=(-1.75 + 0.38, 0.80), arrowprops=dict(arrowstyle='<->, head_width=0.1'))
plt.text(-1.75 + 0.15, 0.9, r'$\gamma$', fontsize=40)

plt.annotate(s='', xy=(-1.75, 0.73), xytext=(-1.75, 0.73 - 0.38), arrowprops=dict(arrowstyle='<->, head_width=0.1'))
plt.text(-1.75 - 0.25, 0.5, r'$\gamma$', fontsize=40)

plt.plot(-1.75, 0.75, 'k', markersize=10, marker = 'o')
plt.plot(-1.75 + 0.3, 0.75 - 0.3, 'k', markersize=10, marker = 'o')

ax.annotate("Current Solution",
            xy=(-1.75, 0.8), xycoords='data', 
            xytext=(-1.95, 1.25), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle3,angleA=0,angleB=90"),
            )

ax.annotate("Next Solution",
            xy=(-1.75 + 0.3, 0.7 - 0.3), xycoords='data', 
            xytext=(-1, -0.5), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle3,angleA=0,angleB=90"),
            )

ax.set_yticklabels([])
ax.set_xticklabels([])
# plt.axis('off')
plt.axis('square')
# plt.savefig('SaDe_2.png')
# Out:
# <ipython-input-184-17b23fcd56a8>:24: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.annotate(s='', xy=(-1.75, 0.8), xytext=(-1.75 + 0.38, 0.80), arrowprops=dict(arrowstyle='<->, head_width=0.1'))
# <ipython-input-184-17b23fcd56a8>:27: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.annotate(s='', xy=(-1.75, 0.73), xytext=(-1.75, 0.73 - 0.38), arrowprops=dict(arrowstyle='<->, head_width=0.1'))
# (-2.0, 1.9000000000000035, -2.0, 1.9000000000000035)

# %%
delta = 0.1
x = np.arange(-2.0, 2.0, delta)
y = np.arange(-2, 2, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(0.3*(-X**2 - 3*Y**2))
# Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
# Z = (Z1 - Z2) * 2

fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (10, 10)
# plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 35
plt.rcParams.update({'figure.autolayout': True})

CS = ax.contour(X, Y, Z1, linewidths=2)
# ax.set_title('SaDe: Satisfiability Descent')

pac = mpatches.Wedge([-1.75, 0.75], 0.5, theta1=270, theta2=360, facecolor='xkcd:grey', edgecolor='grey', ls = '--', alpha=0.3)
plt.gca().add_patch(pac)

plt.annotate(s='', xy=(-1.75, 0.8), xytext=(-1.75 + 0.5, 0.80), arrowprops=dict(arrowstyle='<->, head_width=0.1'))
plt.text(-1.75 + 0.2, 0.85, r'$\alpha$', fontsize=40)

plt.annotate(s='', xy=(-1.8, 0.78), xytext=(-1.8, 0.8 - 0.55), arrowprops=dict(arrowstyle='<->, head_width=0.1'))
plt.text(-1.8 - 0.2, 0.5, r'$\alpha$', fontsize=40)

plt.plot(-1.75, 0.75, 'k', markersize=10, marker = 'o')

ax.annotate("Current Solution",
            xy=(-1.75, 0.8), xycoords='data', 
            xytext=(-1.95, 1.25), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle3,angleA=0,angleB=90"),
            )

ax.set_yticklabels([])
ax.set_xticklabels([])
# plt.axis('off')
plt.axis('square')
# plt.savefig('SaDe_2.png')
# Out:
# <ipython-input-183-e6e203a41290>:23: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.annotate(s='', xy=(-1.75, 0.8), xytext=(-1.75 + 0.5, 0.80), arrowprops=dict(arrowstyle='<->, head_width=0.1'))
# <ipython-input-183-e6e203a41290>:26: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.annotate(s='', xy=(-1.8, 0.78), xytext=(-1.8, 0.8 - 0.55), arrowprops=dict(arrowstyle='<->, head_width=0.1'))
# (-2.0, 1.9000000000000035, -2.0, 1.9000000000000035)

# %%
delta = 0.1
x = np.arange(-2.0, 2.0, delta)
y = np.arange(-2, 2, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(0.3*(-X**2 - 3*Y**2))
# Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
# Z = (Z1 - Z2) * 2

fig, ax = plt.subplots(1, 4)
plt.rcParams["figure.figsize"] = (20, 20)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 15
plt.rcParams.update({'figure.autolayout': True})

for i in range(5):
    CS = ax[i].contour(X, Y, Z1, linewidths=0.6)
    # ax.set_title('SaDe: Satisfiability Descent')
    ax[i].plot(-1.75, 0.75, 'k*')
    if i == 0:
        ax[i].annotate("Starting \nSolution",
            xy=(-1.75, 0.75), xycoords='data', 
            xytext=(-1.75, 1.75), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

    if i == 1:
        pac = mpatches.Wedge([-1.75, 0.75], 0.5, theta1=270, theta2=360, facecolor='xkcd:grey', edgecolor='black', ls = '--', alpha=0.3)
        ax[i].add_patch(pac)
        ax[i].annotate("Solution \nRegion with gradient \ndirection [1, -1]",
            xy=(-1.75 + 0.4, 0.75 - 0.1), xycoords='data', 
            xytext=(-1.75 + 1, 1.75), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )
        
    if i > 1:
        pac = mpatches.Wedge([-1.75, 0.75], 0.5, theta1=270, theta2=360, facecolor='xkcd:grey', edgecolor='black', ls = '--', alpha=0.3)
        ax[i].add_patch(pac)
        ax[i].arrow(-1.75, 0.75, 0.25, -0.3, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)
        if i == 2:
            ax[i].annotate("Next \nSolution",
            xy=(-1.75 + 0.25, 0.75 - 0.3), xycoords='data', 
            xytext=(-1.75 + 1, 1.75), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )
    
    if i > 2:
        pac = mpatches.Wedge([-1.75 + 0.25, 0.75 - 0.3], 0.5, theta1=270, theta2=360, facecolor='xkcd:grey', edgecolor='black', ls = '--', alpha=0.3)
        ax[i].add_patch(pac)
        ax[i].arrow(-1.75 + 0.25, 0.75 - 0.3, 0.4, -0.15, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)
    
    if i > 3:
        pac = mpatches.Wedge([-1.75 + 0.25 + 0.4, 0.75 - 0.3 - 0.15], 0.5, theta1=270, theta2=360, facecolor='xkcd:grey', edgecolor='black', ls = '--', alpha=0.3)
        ax[i].add_patch(pac)
        ax[i].arrow(-1.75 + 0.25 + 0.4, 0.75 - 0.3 - 0.15, 0.3, -0.35, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)
    
    if i > 0:
        ax[i].annotate(s='', xy=(-1.75, 0.8), xytext=(-1.75 + 0.5, 0.80), arrowprops=dict(arrowstyle='<->'))
        ax[i].text(-1.75 + 0.2, 0.85, r'$\alpha$', fontsize=15)

    ax[i].set_yticklabels([])
    ax[i].set_xticklabels([])
    # plt.axis('off')
    ax[i].axis('square')
plt.savefig('SaDe_iteration.png')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-44-7238c276ec3b> in <module>
#      16
#      17 for i in range(5):
# ---> 18     CS = ax[i].contour(X, Y, Z1, linewidths=0.6)
#      19     # ax.set_title('SaDe: Satisfiability Descent')
#      20     ax[i].plot(-1.75, 0.75, 'k*')
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (17, 10)
axes = plt.gca()
axes.set_xlim([0, 2.5])
axes.set_ylim([0, 2.5])

plt.xlabel('$\mathregular{w_1}$')
plt.ylabel('$\mathregular{w_2}$')
pac = mpatches.Rectangle([0, 0], 2, 2, color='blue', alpha=0.1)
plt.gca().add_patch(pac)

pac = mpatches.Wedge([1, 1], 0.75, theta1=0, theta2=360, color='red', alpha=0.1)
plt.gca().add_patch(pac)

pac = mpatches.Wedge([1, 1], 0.75, theta1=90, theta2=180, color='grey', alpha=0.5)
plt.gca().add_patch(pac)

plt.plot([1,  1.5], [1, 1.55], 'blue', lw=1, ls='--', alpha=1)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 50
plt.rcParams.update({'figure.autolayout': True})


ax.annotate("Current \nSolution",
            xy=(1, 1), xycoords='data', 
            xytext=(2.2, 0.75), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

ax.annotate("Full Hypothesis \nSpace",
            xy=(2, 1.75), xycoords='data',
            xytext=(2.5, 1.5), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

ax.annotate("Hypothesis Space \n" r"$\mathbf{w \pm \alpha}$",
            xy=(1.5, 0.4), xycoords='data',
            xytext=(2.2, 0.1), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

ax.annotate("Hypothesis Space limited \nto gradient sign",
            xy=(0.75, 1.2), xycoords='data',
            xytext=(0.3, 2.2), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )


plt.plot([1, 1], [0.25, 1.75], 'black', lw=1, ls='--', alpha=0.3)
plt.plot([0.25, 1.75], [1, 1], 'black', lw=1, ls='--', alpha=0.3)

plt.text(1.3, 1.25, r'$\mathbf{\alpha}$')
# plt.arrow(1, 1, 1.2, 0, length_includes_head=True, head_width=0.04, head_length=0.02)

plt.plot(1, 1, 'b*')

plt.savefig('SaDe_HS.png', bbox_inches="tight")
plt.show()

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (5, 5)
axes = plt.gca()
axes.set_xlim([0, 5])
axes.set_ylim([0, 5])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 18


plt.xlabel('$\mathregular{w_1}$')
plt.ylabel('$\mathregular{w_2}$')

x = np.linspace(-5,5,100)
ax.axhline(y=0, color='k', lw = 0.3, ls = '--')
ax.axvline(x=0, color='k', lw = 0.3, ls = '--')
plt.plot(x, (2 - 2*x), '-b', lw = 0.2)
plt.fill_betweenx([-2, 5], [2, -1.5], [5, 5], color='blue', alpha=0.1)
ax.annotate("$\mathbf{2\mathregular{w_1} + \mathregular{w_2} > 2}$ \n ([2, 1], 1)",
            xy=(0.5, 4.5), xycoords='data', 
            xytext=(-3.5, 4.5), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )


plt.plot(x, (-2 + 2*x), '-r', lw = 0.1)
plt.fill_betweenx([-2, 5], [0, 3.5], [5, 5], color='red', alpha=0.1)
ax.annotate("$\mathbf{-2\mathregular{w_1} + \mathregular{w_2} < -2}$ \n ([-2, 1], 0)",
            xy=(4, 1), xycoords='data', 
            xytext=(5.5, 1), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )


plt.plot(x, (x - 1), 'green', lw = 0.1)
plt.plot(x, (x + 1), 'green', lw = 0.1)
plt.fill_betweenx([-2, 5], [-3, 4], [-1, 6], color='green', alpha=0.1)
ax.annotate("Knowledge: $\mathbf{|\mathregular{w_1} - \mathregular{w_2}| < 1}$",
            xy=(0.5, 0.5), xycoords='data', 
            xytext=(-5, 0.5), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

ax.annotate("Subspace where the solution lies",
            xy=(4.5, 4.5), xycoords='data', 
            xytext=(5.5, 4.5), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

# plt.plot([2], [1], marker='o', markersize=3, color="blue")

plt.plot([1, 3], [0, 4], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([1, 5], [0, 4], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([5, 5], [4, 5], 'black', lw=4, ls='--', alpha=0.3)
plt.plot([4, 5], [5, 5], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([3, 4], [4, 5], 'black', lw=3, ls='--', alpha=0.3)

plt.savefig('MaxSMT_Framework.png', bbox_inches="tight")


# plt.plot([-2], [0.8], marker='o', markersize=3, color="green")

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (5, 5)
axes = plt.gca()
axes.set_xlim([-6.05, 6.05])
axes.set_ylim([-6.05, 6.05])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 15


plt.xlabel('$\mathregular{w_1}$')
plt.ylabel('$\mathregular{w_2}$')

x = np.linspace(-6,6,100)
ax.axhline(y=0, color='k', lw = 0.3, ls = '--')
ax.axvline(x=0, color='k', lw = 0.3, ls = '--')
plt.plot(x, (2 - 2*x), '-b', lw = 0.2)
plt.fill_betweenx([-6, 6], [4, -2], [6, 6], color='blue', alpha=0.1)
ax.annotate("$\mathbf{2\mathregular{w_1} + \mathregular{w_2} > 2}$ \n ([2, 1], 1)",
            xy=(3, 5), xycoords='data', 
            xytext=(7, 5), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )


plt.plot(x, (-2 + 2*x), '-r', lw = 0.1)
plt.fill_betweenx([-6, 6], [-2, 4], [6, 6], color='red', alpha=0.1)
ax.annotate("$\mathbf{-2\mathregular{w_1} + \mathregular{w_2} < -2}$ \n ([-2, 1], 0)",
            xy=(2, -4), xycoords='data', 
            xytext=(7, -4), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )


plt.plot(x, (-3 - 6*x), '-k', lw = 0.1)
plt.fill_betweenx([-6, 6], [0.5, -1.5], [-6, -6], color='black', alpha=0.1)
ax.annotate("$\mathbf{4\mathregular{w_1} + 2/3*\mathregular{w_2} < -2}$ \n ([4, 2/3], 0)",
            xy=(-4, 2), xycoords='data', 
            xytext=(-14, 2), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )


plt.plot([1, 4], [0, -6], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([1, 4], [0, 6], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([4, 6], [-6, -6], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([4, 6], [6, 6], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([6, 6], [-6, 6], 'black', lw=3, ls='--', alpha=0.3)

plt.plot([-2, 0.5], [-6, -6], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([-1/8, 0.5], [-9/4, -6], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([-1/8, -2], [-9/4, -6], 'black', lw=3, ls='--', alpha=0.3)

plt.plot([-2, -1.5], [6, 6], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([-2, -5/4], [6, 9/2], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([-1.5, -5/4], [6, 9/2], 'black', lw=3, ls='--', alpha=0.3)

plt.savefig('MaxSMT_Framework_1.png', bbox_inches="tight")

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (5, 5)
axes = plt.gca()
axes.set_xlim([-6.05, 6.05])
axes.set_ylim([-6.05, 6.05])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 15


plt.xlabel('$\mathregular{w_1}$')
plt.ylabel('$\mathregular{w_2}$')

x = np.linspace(-6,6,100)
ax.axhline(y=0, color='k', lw = 0.3, ls = '--')
ax.axvline(x=0, color='k', lw = 0.3, ls = '--')
plt.plot(x, (2 - 2*x), '-b', lw = 0.2)
plt.fill_betweenx([-6, 6], [4, -2], [6, 6], color='blue', alpha=0.1)
ax.annotate("$\mathbf{2\mathregular{w_1} + \mathregular{w_2} > 2}$ \n ([2, 1], 1)",
            xy=(3, 5), xycoords='data', 
            xytext=(7, 5), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )


plt.plot(x, (-2 + 2*x), '-r', lw = 0.1)
plt.fill_betweenx([-6, 6], [-2, 4], [6, 6], color='red', alpha=0.1)
ax.annotate("$\mathbf{-2\mathregular{w_1} + \mathregular{w_2} < -2}$ \n ([-2, 1], 0)",
            xy=(2, -4), xycoords='data', 
            xytext=(7, -4), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )


plt.plot(x, (-3 - 6*x), '-k', lw = 0.1)
plt.fill_betweenx([-6, 6], [0.5, -1.5], [-6, -6], color='black', alpha=0.1)
ax.annotate("$\mathbf{4\mathregular{w_1} + 2/3*\mathregular{w_2} < -2}$ \n ([4, 2/3], 0)",
            xy=(-4, 2), xycoords='data', 
            xytext=(-14, 2), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )


plt.plot(x, (x - 1), 'green', lw = 0.2)
plt.plot(x, (x + 1), 'green', lw = 0.2)
plt.fill_betweenx([-6, 6], [-7, 5], [-5, 7], color='green', alpha=0.2)
ax.annotate("Knowledge: $\mathbf{|\mathregular{w_1} - \mathregular{w_2}| < 1}$",
            xy=(-4, -4.5), xycoords='data', 
            xytext=(-16.5, -4.5), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

ax.annotate("Subspace where the solution lies",
            xy=(4.5, 4.5), xycoords='data', 
            xytext=(6.5, 3.5), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

plt.plot([1, 3], [0, 4], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([1, 6], [0, 5], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([6, 6], [5, 6], 'black', lw=4, ls='--', alpha=0.3)
plt.plot([5, 6], [6, 6], 'black', lw=3, ls='--', alpha=0.3)
plt.plot([3, 5], [4, 6], 'black', lw=3, ls='--', alpha=0.3)

plt.savefig('MaxSMT_Framework_2.png', bbox_inches="tight")

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (10, 10)
axes = plt.gca()
axes.set_xlim([-5, 6.05])
axes.set_ylim([-5, 6.05])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 35


plt.xlabel('$\mathregular{w_1}$')
plt.ylabel('$\mathregular{w_2}$')

x = np.linspace(-6,6,100)
ax.axhline(y=0, color='k', lw = 0.3, ls = '--')
ax.axvline(x=0, color='k', lw = 0.3, ls = '--')
plt.plot(x, (2 - 2*x), '-b', lw = 0.2)
plt.fill_betweenx([-6, 6], [4, -2], [6, 6], color='blue', alpha=0.1)
# ax.annotate("$\mathbf{2\mathregular{w_1} + \mathregular{w_2} > 2}$ \n ([2, 1], 1)",
#             xy=(-1.3, 5), xycoords='data', 
#             xytext=(-11, 5), textcoords='data',
#             arrowprops=dict(arrowstyle="->",
#                             connectionstyle="arc3"),
#             )


plt.plot(x, (-6 + 3*x), '-r', lw = 0.1)
plt.fill_betweenx([-6, 6], [0, 4], [6, 6], color='red', alpha=0.1)
# ax.annotate("$\mathbf{-\mathregular{w_1} + 1/3*\mathregular{w_2} < -2}$ \n ([-1, 1/3], 0)",
#             xy=(2, -3), xycoords='data', 
#             xytext=(7, -0.5), textcoords='data',
#             arrowprops=dict(arrowstyle="->",
#                             connectionstyle="arc3"),
#             )


plt.plot(x, (x - 1), 'green', lw = 0.2)
plt.plot(x, (x + 1), 'green', lw = 0.2)
plt.fill_betweenx([-6, 6], [-7, 5], [-5, 7], color='green', alpha=0.2)
# ax.annotate("Knowledge: $\mathbf{|\mathregular{w_1} - \mathregular{w_2}| < 1}$",
#             xy=(-1, -0.5), xycoords='data', 
#             xytext=(-14, -0.5), textcoords='data',
#             arrowprops=dict(arrowstyle="->",
#                             connectionstyle="arc3"),
#             )


plt.plot([5/2, 6], [3/2, 5], 'black', lw=6, ls='--', alpha=0.3)
plt.plot([5/2, 7/2], [3/2, 9/2], 'black', lw=6, ls='--', alpha=0.3)
plt.plot([6, 6], [5, 6], 'black', lw=6, ls='--', alpha=0.3)
plt.plot([5, 6], [6, 6], 'black', lw=6, ls='--', alpha=0.3)
plt.plot([7/2, 5], [9/2, 6], 'black', lw=6, ls='--', alpha=0.3)


plt.plot(1, -4, 'r*', markersize=10, marker = 'o')
plt.plot(1, 4, 'b*', markersize=10, marker = 'o')
plt.plot(4, 4, 'g*', markersize=10, marker = 'o')


plt.savefig('MaxSMT_Framework_1.png', bbox_inches="tight")

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (10, 10)
axes = plt.gca()
axes.set_xlim([-5, 6])
axes.set_ylim([-5, 6])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 35

plt.plot(2, 1, 'k*', markersize=10, marker = 'o')
plt.plot(-1, 1.5/3, 'k*', markersize=10, marker = 'o')

ax.axhline(y=0, color='k', lw = 0.3, ls = '--')
ax.axvline(x=0, color='k', lw = 0.3, ls = '--')

plt.plot(x, (1/4*x), '-r', lw = 3)
plt.plot(x, (-1/4*x), '-b', lw = 3)
plt.plot(x, (-1*x), '-g', lw = 3)

plt.xlabel('$\mathregular{x_1}$')
plt.ylabel('$\mathregular{x_2}$')
# Out:
# Text(0, 0.5, '$\\mathregular{x_2}$')

# %%
import altair as alt
from vega_datasets import data

# %%
cars = data.cars()
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...

# %%
alt.Chart(cars).mark_point().encode(
    x = 'Miles_per_Gallon',
    y = 'Acceleration',
    color = 'Origin', tooltip='Name'
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(cars).mark_bar().encode(
    x = alt.X('Miles_per_Gallon', bin=True),
    y = alt.Y('Horsepower', bin=True),
    color = 'count()'
)
# Out:
# alt.Chart(...)

# %%
import matplotlib
import numpy as np
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches

# %%
delta = 0.1
x = np.arange(-2.0, 2.0, delta)
y = np.arange(-2, 2, delta)
X, Y = np.meshgrid(x, y)
Z1 = np.exp(0.3*(-X**2 - 3*Y**2))
# Z2 = np.exp(-(X - 1)**2 - (Y - 1)**2)
# Z = (Z1 - Z2) * 2

fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (15, 15)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 50
plt.rcParams.update({'figure.autolayout': True})

CS = ax.contour(X, Y, Z1, linewidths=2)
# ax.set_title('SaDe: Satisfiability Descent')

pac = matplotlib.patches.Rectangle([-1.75, 0.75], 0.5, -0.5, facecolor='xkcd:grey', edgecolor='grey', ls = '--', alpha=0.3)
plt.gca().add_patch(pac)
plt.arrow(-1.75, 0.75, 0.25, -0.3, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

plt.plot(-1.75 + 0.25, 0.75 - 0.3, 'b*', markersize=5, marker = 'o')

pac = matplotlib.patches.Rectangle([-1.75 + 0.25, 0.75 - 0.3], 0.5, -0.5, facecolor='xkcd:grey', edgecolor='grey', ls = '--', alpha=0.3)
plt.gca().add_patch(pac)
plt.arrow(-1.75 + 0.25, 0.75 - 0.3, 0.4, -0.15, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

pac = pac = matplotlib.patches.Rectangle([-1.75 + 0.25 + 0.4, 0.75 - 0.3 - 0.15], 0.5, -0.5, facecolor='xkcd:grey', edgecolor='grey', ls = '--', alpha=0.3)
plt.gca().add_patch(pac)
plt.arrow(-1.75 + 0.25 + 0.4, 0.75 - 0.3 - 0.15, 0.3, -0.35, length_includes_head=True, head_width=0.04, head_length=0.02, linewidth=2)

plt.annotate(s='', xy=(-1.75, 0.8), xytext=(-1.75 + 0.5, 0.80), arrowprops=dict(arrowstyle='<->'))
plt.text(-1.75 + 0.2, 0.85, r'$\alpha$', fontsize=60)


ax.annotate("Solution learned\n by MaxSMT",
            xy=(-1.75 + 0.25, 0.75 - 0.3), xycoords='data',
            xytext=(-1.75 + 0.4, 1.20), textcoords='data',
            fontsize=30,
            arrowprops=dict(arrowstyle="-|>",
                            connectionstyle="arc3"),
            )

ax.set_yticklabels([])
ax.set_xticklabels([])
# plt.axis('off')
plt.axis('square')
plt.savefig('SaDe_2.png')
# Out:
# <ipython-input-107-a35779d7ac33>:34: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.annotate(s='', xy=(-1.75, 0.8), xytext=(-1.75 + 0.5, 0.80), arrowprops=dict(arrowstyle='<->'))

# %%
fig, ax = plt.subplots()
plt.rcParams["figure.figsize"] = (16, 10)
axes = plt.gca()
axes.set_xlim([0, 2.5])
axes.set_ylim([0, 2.5])

plt.xlabel('$\mathregular{w_1}$')
plt.ylabel('$\mathregular{w_2}$')
pac = mpatches.Rectangle([0, 0], 2, 2, color='blue', alpha=0.1)
plt.gca().add_patch(pac)

pac = matplotlib.patches.Rectangle([0.25, 0.25], 1.5, 1.5, color='red', alpha=0.1)
plt.gca().add_patch(pac)

pac = matplotlib.patches.Rectangle([0.25, 1], 0.75, 0.75, color='grey', alpha=0.6)
plt.gca().add_patch(pac)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.rcParams["font.weight"] = "bold"
plt.rcParams["axes.labelweight"] = "bold"
plt.rcParams["axes.titleweight"] = "bold"
matplotlib.rcParams['font.size'] = 50
plt.rcParams.update({'figure.autolayout': True})


ax.annotate("Current \nSolution",
            xy=(1, 1), xycoords='data', 
            xytext=(2.2, 0.75), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

ax.annotate("Full Hypothesis \nSpace",
            xy=(2, 1.75), xycoords='data',
            xytext=(2.5, 1.5), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

ax.annotate("Hypothesis Space \n" r"$\mathbf{w \pm \alpha}$",
            xy=(1.5, 0.4), xycoords='data',
            xytext=(2.2, 0.1), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )

ax.annotate("Hypothesis Space limited \nto gradient sign",
            xy=(0.75, 1.2), xycoords='data',
            xytext=(0.3, 2.2), textcoords='data',
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="arc3"),
            )


plt.plot([1, 1], [0.25, 1.75], 'black', lw=1, ls='--', alpha=0.3)
plt.plot([0.25, 1.75], [1, 1], 'black', lw=1, ls='--', alpha=0.3)

plt.plot([0.25,  1], [1, 1], 'blue', lw=5, ls='--', alpha=1)
plt.text(0.5, .7, r'$\mathbf{\alpha}$')
# plt.arrow(1, 1, 1.2, 0, length_includes_head=True, head_width=0.04, head_length=0.02)

plt.plot(1, 1, 'b*', markersize=10, marker = 'o')

plt.savefig('SaDe_HS.png', bbox_inches="tight")
plt.show()
